# %%
import tensorflow as tf # pip install tensorflow

# %%
import numpy as np # pip install numpy

# %%
filename = 'C:/Project/Unsupervised Learning/Img/taxi.jpg' # Use any image

# %% [markdown]
# # First method to load an image

# %%
from IPython.display import Image # read image
Image(filename = 'C:/Project/Unsupervised Learning/Img/taxi.jpg', width = 224, height = 224)

# %% [markdown]
# # Second method to load an image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
import  matplotlib.pyplot as plt # conda install -c conda-forge matplotlib

# %%
plt.imshow(img)

# %% [markdown]
# # Third method to load an image

# %%
import cv2 # pip install opencv-python

# %%
imgg = cv2.imread(filename)

# %%
plt.imshow(imgg)

# %%
imgg = cv2.resize(imgg, (224,224))

# %%
plt.imshow(imgg)

# %%
plt.imshow(cv2.cvtColor(imgg, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Fourth method to load an image

# %%
from PIL import Image # pip install Pillow

# %%
im = Image.open(filename) # PIL

# %%
im = im.resize((224,224))

# %%
plt.imshow(im)

# %% [markdown]
# # Lets load the deep learning model

# %%
mobile = tf.keras.applications.mobilenet.MobileNet() #Deep learning model weights pre-trained

# %%
# Loading using MobileNetV2

# %%
mobile = tf.keras.applications.mobilenet_v2.MobileNetV2()

# %% [markdown]
# # Pre-processing the image

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(filename, target_size = (224,224))

# %%
plt.imshow(img)

# %%
resized_img = image.img_to_array(img)
final_image = np.expand_dims(resized_img,axis = 0) # Creating fourth dimension
final_image = tf.keras.applications.mobilenet.preprocess_input(final_image)

# %%
final_image.shape
# Out:
# (1, 224, 224, 3)

# %%
predictions = mobile.predict(final_image)

# %%
from tensorflow.keras.applications import imagenet_utils

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n02930766', 'cab', 0.9999491), ('n04146614', 'school_bus', 4.6869347e-05), ('n03977966', 'police_van', 1.499157e-06), ('n02701002', 'ambulance', 6.7221293e-07), ('n04285008', 'sports_car', 4.0684068e-07)]]

# %%
predictions = mobile.predict(final_image) # predicting using MobileNetV2

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
print(results)
# Out:
# [[('n02930766', 'cab', 0.99925214), ('n04146614', 'school_bus', 0.0003723025), ('n02701002', 'ambulance', 4.454473e-05), ('n03977966', 'police_van', 2.9899644e-05), ('n06874185', 'traffic_light', 1.7900573e-05)]]
